# %%
# 실습_상관관계
middle_scores = [90,60,50,96,80,87,100,65,98,90,85,60]   # 중간고사
final_scores = [85,65,60,80,80,92,91,80,100,87,75,85]     # 기말고사

import matplotlib.pyplot as plt

plt.scatter(middle_scores,final_scores)
plt.show()
