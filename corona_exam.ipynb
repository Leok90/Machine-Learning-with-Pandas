# %%
import pandas as pd

df1 = pd.read_csv("./seoul_corona.csv", sep=",", encoding='cp949')

# %%
# 처음 5개 행 출력
df1.head()
# Out:
#      연번  확진달  확진일   환자번호  국적  환자정보   지역  여행력        접촉력  조치사항   상태 이동경로  \
# 0  5748   10   21  25530 NaN   NaN  양천구  NaN   감염경로 조사중   NaN  NaN  NaN
# 1  5747   10   21  25528 NaN   NaN  강동구  NaN  강남서초 지인모임   NaN  NaN  NaN
# 2  5746   10   21  25525 NaN   NaN  강남구  NaN  기타 확진자 접촉   NaN  NaN  NaN
# 3  5745   10   21  25517 NaN   NaN  관악구  NaN   감염경로 조사중   NaN  NaN  NaN
# 4  5744   10   21  25504 NaN   NaN  관악구  NaN  기타 확진자 접촉   NaN  NaN  NaN
#
#                 등록일               수정일 노출여부
# 0  2020-10-22 10:58  2020-10-22 10:58    Y
# 1  2020-10-22 10:58  2020-10-22 10:58    Y
# 2  2020-10-22 10:58  2020-10-22 10:58    Y
# 3  2020-10-22 10:58  2020-10-22 10:58    Y
# 4  2020-10-22 10:58  2020-10-22 10:58    Y

# %%
# 마지막 5개 행 출력
df1.tail()
# Out:
#       연번  확진달  확진일  환자번호  국적  환자정보   지역     여행력    접촉력  조치사항  상태  \
# 5743   5    1   31     9 NaN   NaN  성북구     NaN  #5 접촉   NaN  퇴원
# 5744   4    1   30     7 NaN   NaN  마포구  중국 우한시  해외 접촉   NaN  퇴원
# 5745   3    1   30     6 NaN   NaN  종로구     NaN  #3 접촉   NaN  퇴원
# 5746   2    1   30     5 NaN   NaN  중랑구  중국 우한시  해외 접촉   NaN  퇴원
# 5747   1    1   24     2 NaN   NaN  강서구  중국 우한시  해외 접촉   NaN  퇴원
#
#               이동경로               등록일              수정일 노출여부
# 5743  이동경로 공개기간 경과  2020-10-22 10:58  2020-10-23 9:00    Y
# 5744  이동경로 공개기간 경과  2020-10-22 10:58  2020-10-23 9:00    Y
# 5745  이동경로 공개기간 경과  2020-10-22 10:58  2020-10-23 9:00    Y
# 5746  이동경로 공개기간 경과  2020-10-22 10:58  2020-10-23 9:00    Y
# 5747  이동경로 공개기간 경과  2020-10-22 10:58  2020-10-23 9:00    Y

# %%
# 데이터프레임의 크기(행, 열) 확인
df1.shape
# Out:
# (5748, 15)

# %%
# 데이터프레임의 기본 정보를 확인
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5748 entries, 0 to 5747
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      5748 non-null   int64
#  1   확진달     5748 non-null   int64
#  2   확진일     5748 non-null   int64
#  3   환자번호    5748 non-null   int64
#  4   국적      0 non-null      float64
#  5   환자정보    0 non-null      float64
#  6   지역      5748 non-null   object
#  7   여행력     458 non-null    object
#  8   접촉력     5748 non-null   object
#  9   조치사항    0 non-null      float64
#  10  상태      5357 non-null   object
#  11  이동경로    5520 non-null   object
#  12  등록일     5748 non-null   object
#  13  수정일     5748 non-null   object
#  14  노출여부    5748 non-null   object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 673.7+ KB

# %%
df1.describe()
# Out:
#                 연번          확진달          확진일          환자번호   국적  환자정보  조치사항
# count  5748.000000  5748.000000  5748.000000   5748.000000  0.0   0.0   0.0
# mean   2874.500000     7.506089    17.317850  17057.479819  NaN   NaN   NaN
# std    1659.449005     1.923759     8.481592   5078.332051  NaN   NaN   NaN
# min       1.000000     1.000000     1.000000      2.000000  NaN   NaN   NaN
# 25%    1437.750000     7.000000    10.000000  13540.750000  NaN   NaN   NaN
# 50%    2874.500000     8.000000    18.000000  17328.500000  NaN   NaN   NaN
# 75%    4311.250000     9.000000    25.000000  21153.250000  NaN   NaN   NaN
# max    5748.000000    10.000000    31.000000  25530.000000  NaN   NaN   NaN

# %%
df1.count()
# Out:
# 연번      5748
# 확진달     5748
# 확진일     5748
# 환자번호    5748
# 국적         0
# 환자정보       0
# 지역      5748
# 여행력      458
# 접촉력     5748
# 조치사항       0
# 상태      5357
# 이동경로    5520
# 등록일     5748
# 수정일     5748
# 노출여부    5748
# dtype: int64

# %%
# 관악구의 확진자 수를 구하시오. 답: 452
df1['지역'].value_counts()
# Out:
# 관악구     452
# 송파구     361
# 성북구     344
# 타시도     331
# 노원구     323
# 강남구     296
# 강서구     295
# 은평구     259
# 동작구     254
# 도봉구     223
# 서초구     210
# 중랑구     202
# 영등포구    200
# 강동구     199
# 구로구     193
# 양천구     186
# 마포구     180
# 동대문구    172
# 강북구     156
# 용산구     140
# 광진구     136
# 서대문구    135
# 성동구     130
# 기타      117
# 금천구      96
# 종로구      94
# 중구       64
# Name: 지역, dtype: int64

# %%
df1['접촉력'].value_counts()
# Out:
# 기타 확진자 접촉                818
# 성북구 사랑제일교회 관련            641
# 확인 중                     586
# 해외 접촉 추정                 415
# 감염경로 조사중                 373
#                         ...
# 대전 다단계 관련                  1
# #6727 첩촉                   1
# #83 접촉                     1
# 고양시 반석교회(케네디상가)            1
# 타시도 확진자 접촉(강원강릉시지인모임)      1
# Name: 접촉력, Length: 295, dtype: int64

# %%
# '접촉력'이 '감염경로 조사중'이면서, '지역'이 '도봉구'인 확진자 수를 구하시오. 답 : 17
df2 = df1[(df1['접촉력'] == '감염경로 조사중') & (df1['지역'] == '도봉구')]
df2.shape
# Out:
# (17, 15)

# %%
df2
# Out:
#         연번  확진달  확진일   환자번호  국적  환자정보   지역  여행력       접촉력  조치사항   상태  \
# 199   5549   10   11  24633 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN  NaN
# 235   5513   10   10  24569 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN  NaN
# 239   5509   10    9  24531 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN  NaN
# 369   5379   10    4  24118 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# 398   5350   10    2  24012 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN  NaN
# 563   5185    9   26  23562 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# 606   5142    9   24  23427 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN  NaN
# 675   5073    9   22  23255 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# 864   4884    9   17  22726 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# 1118  4630    9   11  21991 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# 1229  4519    9    9  21642 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# 1268  4480    9    9  21612 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# 1290  4458    9    7  21456 NaN   NaN  도봉구  NaN  감염경로 조사중   NaN   퇴원
# ...

# %%
df1['상태'].value_counts()
# Out:
# 퇴원    5283
# 사망      74
# Name: 상태, dtype: int64

# %%
# 사망자가 가장 많은 확진달을 구하시오. 답: 8월
df1[df1['상태'] == '사망']['확진달'].value_counts()
# Out:
# 8     36
# 9     21
# 6      7
# 7      4
# 3      2
# 10     2
# 2      1
# 4      1
# Name: 확진달, dtype: int64

# %%
# 월별 확진자수를 막대그래프로 시각화 하시오.
df1['확진달'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
